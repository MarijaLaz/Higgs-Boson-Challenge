# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy as ski
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv("Data/HEMODB.csv",sep=';')

# %%
data.head()
# Out:
#    ID  Brachial SBP  Brachial DBP  Brachial PP     MAP  Heart rate  \
# 0   1        98.328        73.229       25.098  81.595      85.608
# 1   2        87.134        64.596       22.538  72.109      74.166
# 2   3        85.728        65.301       20.427  72.110      86.010
# 3   4        87.308        68.627       18.681  74.854         NaN
# 4   5        83.572        65.532       18.040  71.545      97.197
#
#    Carotid-to-femoral PWV  Stroke volume  Ejection fraction  Central SBP  \
# 0                  6.2060         50.896             48.893       91.399
# 1                  5.8806         51.110             48.303       80.663
# 2                  6.0619         45.413             41.588       79.826
# 3                  5.9547         45.091             39.257       81.771
# 4                  5.7352         41.302             39.403       78.667
#
#    End-systolic elastance  End-diastolic elastance  Ejection duration  \
# ...

# %%
# Removal of the unused features, keeping brSBP, brDBP, HR and cfPWV
u_features=[data['Brachial SBP'],data['Brachial DBP'],data['Heart rate'],data['Carotid-to-femoral PWV']]
used_features=pd.DataFrame(u_features)
print(used_features)

#Second set of used features, adding EF
u2_features=[data['Brachial SBP'],data['Brachial DBP'],data['Heart rate'],data['Carotid-to-femoral PWV'],data['Ejection fraction']]
used2_features=pd.DataFrame(u2_features)
print(used2_features)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'brSBP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-ec1a024dc67a> in <module>
# ...
